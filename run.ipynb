# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -r /content/drive/MyDrive/Aspect-base_SA/UCE/code_ace/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 1.7MB 30.3MB/s
# ...
#      |████████████████████████████████| 22.3MB 2.4MB/s
# ...
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# ...

# %%
# %cd /content/drive/MyDrive/Aspect-base_SA/UCE/UCE_without_padding

# from importlib import reload
# import trainer
# reload(trainer)
# %run main.py --train_data "/content/drive/MyDrive/Aspect-base_SA/preprocessed_data/restaurant/data_wmf/traing_3labels" \
--test_data "/content/drive/MyDrive/Aspect-base_SA/preprocessed_data/restaurant/data_wmf/test" \
--seed_data "/content/drive/MyDrive/Aspect-base_SA/preprocessed_data/restaurant/seed3.txt" \
--w2v "/content/drive/MyDrive/Aspect-base_SA/preprocessed_data/restaurant/data_wmf/word2vec.txt" \
--lr 0.00001 \
--anpha 1 \
--lamda 0 \
--is_train 1 \
--batchsize 512 \
--n_epoch 5 \
--des "" \
--start_epoch 0 \
--maxlen 30 \
--save_initmodel 0 \
--threshold 1 \
--number_loss 0 \
--phi 0 \
--maxlen_seed 5 \
--num_cluster_general 200 \
--num_cluster_aspects 1 \
--maxlen_seed_aspects 5 \
--general_idx 80 
# --pretrain_model "/content/drive/MyDrive/Aspect-base_SA/code1/WMF/save_model/Restaurant-Jasenfscore=0.6772116185025194epoch=20use_att=False"
# Out:
# /content/drive/MyDrive/Aspect-base_SA/UCE/UCE_without_padding
# ...

# %%
import test
a = torch.load("/content/drive/MyDrive/Aspect-base_SA/preprocessed_data/restaurant/data_wmf/test")
a[0]
# Out:
# ['staff friendliest competent stickler service everything else place make', 2]
